# %%
from sklearn.datasets import make_blobs
import numpy as np
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
import random 
# %matplotlib inline

# %% [markdown]
# # Generating the datasets

# %%
X,y=make_blobs(n_samples=1000,centers=2,random_state=0)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# # Predefined Function For KMeans

# %%
model=KMeans(n_clusters=5)

# %%
model.fit(X)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=5, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
center=model.cluster_centers_
print(center)
# Out:
# [[ 1.17539988  2.64169439]
#  [ 1.63205568  4.79654587]
#  [ 2.86802307  1.02276823]
#  [ 0.03477081  4.46834914]
#  [ 1.45525914  0.18357884]]

# %%
#labels=model.labels_
#print(labels)

# %%
plt.scatter(X[:,0],X[:,1],c=model.labels_,s=12)
for center in center:
    plt.scatter(center[0],center[1])

# %% [markdown]
# # Self Made KMeans

# %%
X,y=make_blobs(n_samples=1000,centers=2,random_state=0)

# %%
class KMeans:
    
    def __init__(self,n_clusters,iters=10):
        self.n_clusters=n_clusters
        self.iters=iters
    
    def fit(self,X):
        self.X=X
        
        points=random.choices(list(X),k=self.n_clusters) #Generating random n points as centers for n_clusters or n seed points
        
        # Create cluster corresponding to seed points
        self.clusters=[]
        for point in points:
            cluster=Cluster(point) #Created an object of Cluster class
            self.clusters.append(cluster)
            
        for _ in range(self.iters): # Running full loop again again for accuracy
            
            self.labels_=[]
            for point in X:
                distances=[]
                for cluster in self.clusters:
                    dis=cluster.distance(point)
                    distances.append((dis,cluster))
                distances_np=np.array(distances) # Converting list of all the distances of a point from all centers
                
                min_index=np.argmin(distances_np[:,0].astype(int))
                selected_cluster=self.cluster[min_index]
                selected_cluster.points.append(point)
                self.labels_.append(min_index)
                
            for cluster in self.clusters:
                cluster.update_center()
                
    def error(self):
        total=0
        for point, label in zip(self.X,self.labels_):
            dis=self.clusters[label].distance(point)
            total+=dis
        return total
        
            
            
class Cluster:
    
    def __init__(self,center):
        self.center=center
        self.points=[]
        
    def update_center(self):
        self.center = np.mean(self.points,axis=0)
        self.points=[]
        
    def distance(self,point):
        return np.sum((self.center-point)**2)
    
    def __repr__ (self):
        return self.cluster
# Out:
#   File "<ipython-input-15-125f8ee8fd51>", line 40
#     class Cluster:
#                   ^
# IndentationError: expected an indented block

# %%
model=KMeans(4)

# %%
model.fit(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0ec63935afdf> in <module>()
# ----> 1 model.fit(X)
#
# <ipython-input-12-e5199d8d9601> in fit(self, X)
#       8         self.X=X
#       9
# ---> 10         points=random.choices(list(X),k=self.n_clusters) #Generating random n points as centers for n_clusters or n seed points
#      11
#      12         # Create cluster corresponding to seed points
#
# AttributeError: module 'random' has no attribute 'choices'

# %%
import random
print (random.__file__)
# Out:
# C:\Users\Tanish Saxena\Anaconda3\lib\random.py
