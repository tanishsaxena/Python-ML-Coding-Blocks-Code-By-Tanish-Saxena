# %%
from keras.models import Model
from keras.layers import Dense #This is the layer which shows the layer is connected to all previous neuron
from keras.layers import Input
#from sklearn.datasets import make_circles
#from keras.losses import categorical_crossentropy
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import numpy as np
from keras.layers import Conv2D, MaxPool2D, Flatten,Dropout

# %%
data=pd.read_csv("mnist_train_small.csv").values

# %%
X=data[:,2:].reshape(-1,28,28,1) # One is single depth which conv takes

# %%
y=data[:,1]

# %%
plt.imshow(X[0].reshape(28,28)) # Converts the imgae to 2d without depth

# %%
ohe=OneHotEncoder(categories="auto")

# %%
y_hot=ohe.fit_transform(y.reshape(-1,1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_hot, test_size=0.33, random_state=42)

# %%
model=Model()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0709 16:24:24.959722  7652 deprecation_wrapper.py:119] From c:\users\tanish saxena\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
X.shape
# Out:
# (8000, 28, 28, 1)

# %%
in_layer=Input(shape=[28,28,1])# This is showing inputs of first layer
layer_1=Conv2D(32,(3,3), activation="relu")(in_layer)
layer_2=MaxPool2D()(layer_1)
layer_3=Conv2D(64,(3,3), activation="relu")(layer_2)
layer_4=MaxPool2D()(layer_3)
drop=Dropout(.25)(layer_4) #This will switch of 25% neurons
layer_5=Conv2D(128,(3,3), activation="relu")(drop)
layer_6=MaxPool2D()(layer_5)

flatten=Flatten()(layer_6)

d1=Dense(400,activation="relu")(flatten)
d2=Dense(100,activation="relu")(d1)
d3=Dense(50,activation="relu")(d2)
out=Dense(10,activation="softmax")(d3)

# %%
model=Model(inputs=[in_layer],outputs=[out])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 128)         73856
# ...

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
hist=model.fit(X_train,y_train,epochs=6,batch_size=200)
# Out:
# Epoch 1/6
# 5360/5360 [==============================] - 7s 1ms/step - loss: 2.2545 - acc: 0.3711
# Epoch 2/6
# 5360/5360 [==============================] - 6s 1ms/step - loss: 0.6919 - acc: 0.7787
# Epoch 3/6
# 5360/5360 [==============================] - 6s 1ms/step - loss: 0.3883 - acc: 0.8851
# Epoch 4/6
# 5360/5360 [==============================] - 6s 1ms/step - loss: 0.2783 - acc: 0.9172
# Epoch 5/6
# 5360/5360 [==============================] - 6s 1ms/step - loss: 0.2130 - acc: 0.9330
# Epoch 6/6
# 5360/5360 [==============================] - 6s 1ms/step - loss: 0.1738 - acc: 0.9468

# %%
model.evaluate(X_test,y_test)
# Out:
# 2640/2640 [==============================] - 1s 363us/step
# [0.16339936317367987, 0.9477272727272728]

# %% [markdown]
# # Taking outputs from middle layers

# %%
m2=Model(inputs=[in_layer],outputs=[layer_1])
m2.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
res=m2.predict(X_test[:1])
res= res.reshape(26,26,32)
for i in range(res.shape[2]):
    plt.figure()
    img=res[:,:,i]
    plt.imshow(img)
# Out:
# c:\users\tanish saxena\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# # For layer 3

# %%
m3=Model(inputs=[in_layer],outputs=[layer_3])
m3.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
res_3layer=m3.predict(X_test[:1])
res_3layer=res_3layer.reshape(11,11,64)
for j in range(res_3layer.shape[2]):
    plt.figure()
    img=res_3layer[:,:,j]
    plt.imshow(img)
# Out:
# c:\users\tanish saxena\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# # Output of 5th layer

# %%
m5=Model(inputs=[in_layer],outputs=[layer_5])
m5.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
res_5layer=m5.predict(X_test[:1])
res_5layer=res_5layer.reshape(3,3,128)
for j in range(res_5layer.shape[2]):
    plt.figure()
    img=res_5layer[:,:,j]
    plt.imshow(img)
# Out:
# c:\users\tanish saxena\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# # Transfer Learning
# * It is a state in which we cut out any layer from the big model and clip that with our own self made new front layers that is called transfer learning

# %%
combined=model.layers[:-4]

# %%
de1=Dense(400,activation="relu")(combined[-1].output)
de2=Dense(100,activation="relu")(de1)
de3=Dense(50,activation="relu")(de2)
eout=Dense(2,activation="softmax")(de3)

# %%
for layer in combined:
    layer.trainable=False  #In this  if we make it false than it means we dont need to train them again

# %%
model=Model(inputs=[combined[0].input],outputs=[eout])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 128)         73856
# ...

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
y_oddeven_hot=ohe.fit_transform((y%2).reshape(-1,1)).todense()

# %%
model.fit(X,y_oddeven_hot,epochs=10,batch_size=200)
# Out:
# Epoch 1/10
# 8000/8000 [==============================] - 4s 488us/step - loss: 0.4078 - acc: 0.8758
# Epoch 2/10
# 8000/8000 [==============================] - 3s 389us/step - loss: 0.1095 - acc: 0.9597
# Epoch 3/10
# 8000/8000 [==============================] - 3s 409us/step - loss: 0.0986 - acc: 0.9634
# Epoch 4/10
# 8000/8000 [==============================] - 3s 384us/step - loss: 0.0889 - acc: 0.9679
# Epoch 5/10
# 8000/8000 [==============================] - 3s 388us/step - loss: 0.0849 - acc: 0.9684
# Epoch 6/10
# 8000/8000 [==============================] - 3s 389us/step - loss: 0.0795 - acc: 0.9696
# Epoch 7/10
# 8000/8000 [==============================] - 3s 390us/step - loss: 0.0726 - acc: 0.9725
# Epoch 8/10
# 8000/8000 [==============================] - 3s 389us/step - loss: 0.0709 - acc: 0.9729
# Epoch 9/10
# 8000/8000 [==============================] - 3s 416us/step - loss: 0.0711 - acc: 0.9753
# Epoch 10/10
# ...
