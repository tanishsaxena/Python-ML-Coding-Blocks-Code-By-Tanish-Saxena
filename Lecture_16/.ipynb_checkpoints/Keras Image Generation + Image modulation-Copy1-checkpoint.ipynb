# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator 
import numpy as np

# %%
img_=image.load_img("1.png",target_size=(200,200))

# %%
type(img_)
# Out:
# PIL.Image.Image

# %%
img_
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x20822D72198>

# %%
np_img=image.img_to_array(img_).astype(int)

# %%
datagen=ImageDataGenerator(horizontal_flip=True,
                           #vertical_flip=True,
                          zoom_range=2,
                          rotation_range=20,
                          shear_range=.3)

# %%
np_batch=np.array([np_img])

# %%
gen=datagen.flow(np_batch)

# %%
gen.next().shape
# Out:
# (1, 200, 200, 3)

# %%
for i in range(5):
    img=gen.next()[0]
    plt.figure()
    plt.imshow(img.astype(int))
