# %%
import cv2
import matplotlib.pyplot as plt
import pandas
import numpy as np

# %%
img=cv2.imread("1.png")

# %%
plt.imshow(img)

# %%
filtr=np.array([[1,1,1],[0,0,0],[-1,-1,-1]])

# %%
filtr
# Out:
# array([[ 1,  1,  1],
#        [ 0,  0,  0],
#        [-1, -1, -1]])
