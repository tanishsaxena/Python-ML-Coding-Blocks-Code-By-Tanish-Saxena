# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
a=[1,-3,5,-7,9]

# %%
plt.plot(a)

# %% [markdown]
# # rough for random numbers

# %%
a=np.random.randint(0,10,5)

# %%
a
n=[0,1,2,3,4]

# %%
plt.bar(n,a,label="ages")
plt.legend()
plt.show()

# %%
a=np.random.randint(0,10,4)
b=np.random.randint(0,10,4)

x=np.arange(4)
y=np.arange(4)

plt.bar(x,a,0.25,color="red",label="test1")
plt.bar(y+0.25,b,0.25,color="y",label="test2")
plt.legend()
plt.show()
